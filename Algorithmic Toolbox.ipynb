# %%
aplusb = raw_input()
list = aplusb.split()
result =  int(list[0])+int(list[1])
print result
# Out:
# 3 5
# 8

# %%
n = int(raw_input())
fib = []
fib.append(0.)
fib.append(1.)
print fib

for i in range(n):
    if i>=2: fib.append(fib[i-2] + fib[i-1])

print fib
# Out:
# 100
# [0.0, 1.0]
# ...

# %%
def fib(n):
    if n==0: return 0
    if n==1: return 1
    return fib(n-1)+fib(n-2)

n = int(raw_input())
print fib(n)
# Out:
# 50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-57129c5530d7> in <module>()
#       5
#       6 n = int(raw_input())
# ----> 7 print fib(n)
#
# <ipython-input-25-57129c5530d7> in fib(n)
#       2     if n==0: return 0
#       3     if n==1: return 1
# ----> 4     return fib(n-1)+fib(n-2)
#       5
#       6 n = int(raw_input())
#
# <ipython-input-25-57129c5530d7> in fib(n)
#       2     if n==0: return 0
#       3     if n==1: return 1
# ----> 4     return fib(n-1)+fib(n-2)
#       5
#       6 n = int(raw_input())
#
# <ipython-input-25-57129c5530d7> in fib(n)
#       2     if n==0: return 0
#       3     if n==1: return 1
# ----> 4     return fib(n-1)+fib(n-2)
#       5
#       6 n = int(raw_input())
#
# <ipython-input-25-57129c5530d7> in fib(n)
#       2     if n==0: return 0
#       3     if n==1: return 1
# ----> 4     return fib(n-1)+fib(n-2)
# ...

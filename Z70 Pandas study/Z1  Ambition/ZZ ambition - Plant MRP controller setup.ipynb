# %%
import numpy as np
from pandas import Series, DataFrame
import pandas as pd

# %%
#get plant list from clipboard
plant_dfm = pd.read_clipboard()

# %%
plant_dfm
# Out:
#    plant                                plant desc                  type  \
# 0   24LT          LTH LOGITICS (SINGAPORE) PTE LTD             WAREHOUSE
# 1   24CW                    CWT INTEGRATED PTE LTD             WAREHOUSE
# 2   24TE      TRIPLE EAGLE FORWARDING (TAIWAN) LTD             WAREHOUSE
# 3   24AW       ASIAN WAREHOUSING SINGAPORE PTE LTD             WAREHOUSE
# 4   24AU                  AURORA CHEMICALS SDN BHD             WAREHOUSE
# 5   24FC             FALCON CONTAINER TPT CO., LTD             WAREHOUSE
# 6   24JW                JWD INFOLOGISTICS CO., LTD             WAREHOUSE
# 7   24JS           JEONGILSTOLTHAVENULSAN CO., LTD             WAREHOUSE
# 8   24VO         VOPAK TERMINALS SINGAPORE PTE LTD                TOLLER
# 9   24OD          ODFJELL TERMINALS (KOREA) CO LTD                TOLLER
# 10  24PY  PYRAMID MANUFACTURING INDUSTRIES PTE LTD                TOLLER
# 11  24AM          AIK MOH PAINTS PAINTS & CHEM P/L                TOLLER
# 12  24QP                              QPSI PTE LTD                TOLLER
# 13  24KT  KALTECH ENGINEERING & REFRIGERATION PTE   TOLLER AND WAREHOUSE
# 14  2491              ARKEMA PTE LTD (CONSIGNMENT)           CONSIGNMENT
# 15  2490                  ARKEMA PTE LTD (TRADING)               TRADING
# 16  25JH               ARKEMA KOREA (JINHAE PLANT)            PRODUCTION
# 17  25SE    SEOUL RESIN WAREHOUSE (DASI LOGISTICS)             WAREHOUSE
# 18  25HW  HWASUNG RESIN WAREHOUSE(SEJIN LOGISTICS)             WAREHOUSE
# 19  25DG  DAEGU RESIN WAREHOUSE(CHANGRIM POLYMER)              WAREHOUSE
# 20  25BU    BUSAN PORT (HYUNDAI NEW-PORT TERMINAL)             WAREHOUSE
# 21  25UL  ULSAN WAREHOUSE (MMA-JEONGIL STOLTHAVEN)             WAREHOUSE
# 22  25II               IISHIN WAREHOUSE(SARTOMER)              WAREHOUSE
# 23  25KS                              KSCB CO.,LTD                TOLLER
# 24  25YT                        YUJIN TECH CO.,LTD                TOLLER
# 25  25HT                        HANIL TOYO CO.,LTD                TOLLER
# 26  2590                    ARKEMA KOREA (TRADING)               TRADING
# 27  2591                ARKEMA KOREA (CONSIGNMENT)           CONSIGNMENT
# 28  26CO            CHIKKO CORPORATION OSAKA NISHI             WAREHOUSE
# 29  26CY               CHIKKO CORPORATION YOKOHAMA             WAREHOUSE
# ..   ...                                       ...                   ...
# 53  9ISH                               SHANGHAI WH             WAREHOUSE
# 54  9IHS                           GLASSCOATING WH             WAREHOUSE
# 55  9ILF                        LIFAN TANK SERVICE             WAREHOUSE
# 56  9IHE                         HANGQIN EQUIPMENT             WAREHOUSE
# 57  9I91   ARKEMA CHANGHSU CHEMICALS (CONSIGNMENT)           CONSINGMENT
# 58  9I90          ARKEMA CHANGHSU CHEMICALS (TRAD)               TRADING
# 59  9BSH          ARKEMA HYDROGEN PEROXIDE CO.,LTD            PRODUCTION
# 60  9BGZ     GUANGZHOU CONTAINER TERMINAL CO., LTD             WAREHOUSE
# 61  9BYY             EVERLAST TANK CONTAINERS SERV             WAREHOUSE
# 62  9DGQ                    WAIGAOQIAO BONDED ZONE             WAREHOUSE
# 63  9DGU                WAIGAOQIAO NON BONDED ZONE             WAREHOUSE
# 64  9DNH                   SHANGHAI  NANHUI DG WH              WAREHOUSE
# 65  9DYH                    GUANGZHOU YUEHAI DG WH             WAREHOUSE
# 66  9DZU                  GUANGZHOU NON BONDED WH              WAREHOUSE
# 67  9DCU                    CHANGSHU NON BONDED WH             WAREHOUSE
# 68  9DNB                          NINGBO BONDED WH             WAREHOUSE
# 69  9DNU                      NINGBO NON BONDED WH             WAREHOUSE
# 70  9DPU                     PUDONG NON BONDED WH              WAREHOUSE
# 71  9D90   Arkema Shanghai Distribution LTD (TRAD)               TRADING
# 72  7STS          TOPSAFE PETROCHEMICAL LOGISTICS              WAREHOUSE
# 73  7SFS     FOREVERSUN CHEMICAL LOGISTICS CO.,Ltd             WAREHOUSE
# 74  7S90  Arkema Taixing Chemicals Co., Ltd (TRAD)               TRADING
# 75  5KH1               ORIENTAL LOGISTIC Hong Kong             WAREHOUSE
# 76  5KBP                   SHANGHAI WAIGAOQIAO BLP             WAREHOUSE
# 77  5KGQ                  ASD WAIGAOQIAO WAREHOUSE             WAREHOUSE
# 78  5KWM                  WILLMAR TANK TERMINAL,MY             WAREHOUSE
# 79  5KJS                       JSTT KOREA TANK ???             WAREHOUSE
# 80  5KT1                          KSK PLASTICS(SH)             WAREHOUSE
# 81  5K90            SARTOMER ASIA LIMITED(TRADING)               TRADING
# 82  5KFS                           FOREVERSUN TANK             WAREHOUSE
#
#    country company        company desc
# 0       SG      24                 PTE
# 1       SG      24                 PTE
# 2       TW      24                 PTE
# 3       SG      24                 PTE
# 4       MY      24                 PTE
# 5       TH      24                 PTE
# 6       TH      24                 PTE
# 7       KR      24                 PTE
# 8       SG      24                 PTE
# 9       KR      24                 PTE
# 10      SG      24                 PTE
# 11      SG      24                 PTE
# 12      SG      24                 PTE
# 13      SG      24                 PTE
# 14      SG      24                 PTE
# 15      SG      24                 PTE
# 16      KR      25  PMMA&Korea Trading
# 17      KR      25  PMMA&Korea Trading
# 18      KR      25  PMMA&Korea Trading
# 19      KR      25  PMMA&Korea Trading
# 20      KR      25  PMMA&Korea Trading
# 21      KR      25  PMMA&Korea Trading
# 22      KR      25  PMMA&Korea Trading
# 23      KR      25  PMMA&Korea Trading
# 24      KR      25  PMMA&Korea Trading
# 25      KR      25  PMMA&Korea Trading
# 26      KR      25  PMMA&Korea Trading
# 27      KR      25  PMMA&Korea Trading
# 28      JP      26                  KK
# 29      JP      26                  KK
# ..     ...     ...                 ...
# 53      CN      9I                 ACC
# 54      CN      9I                 ACC
# 55      CN      9I                 ACC
# 56      CN      9I                 ACC
# 57      CN      9I                 ACC
# 58      CN      9I                 ACC
# 59      CN      9B                ASHP
# 60      CN      9B                ASHP
# 61      CN      9B                ASHP
# 62      CN      9D                 ASD
# 63      CN      9D                 ASD
# 64      CN      9D                 ASD
# 65      CN      9D                 ASD
# 66      CN      9D                 ASD
# 67      CN      9D                 ASD
# 68      CN      9D                 ASD
# 69      CN      9D                 ASD
# 70      CN      9D                 ASD
# 71      CN      9D                 ASD
# 72      CN      7S                 ATC
# 73      CN      7S                 ATC
# 74      CN      7S                 ATC
# 75      CN      5K                 ACL
# 76      CN      5K                 ACL
# 77      CN      5K                 ACL
# 78      CN      5K                 ACL
# 79      CN      5K                 ACL
# 80      CN      5K                 ACL
# 81      CN      5K                 ACL
# 82      CN      5K                 ACL
#
# [83 rows x 6 columns]

# %%
#get MRP controller
mrp_dfm =pd.read_clipboard()

# %%
mrp_dfm
# Out:
#    company desc MRPC               Name
# 0           ACL  N06        Négoce PASP
# 1           ACL  N14    Négoce Acrylics
# 2           ACL  N61       Négoce Kynar
# 3           ACL  N63    Négoce Sartomer
# 4           ACL  P01          Packaging
# 5           ACL  P06     Packaging PASP
# 6           ACL  R01       Raw material
# 7           ACL  R06  Raw material PASP
# 8           ACL  T01            Tolling
# 9           ACL  T06       Tolling PASP
# 10          ACL  S01             Sample
# 11          ACL  M01        Spare parts
# 12          ACL  M02      Miscellaneous
# 13          ASD  N03   Négoce ADDITIVES
# 14          ASD  N06        Négoce PASP
# 15          ASD  N08  Négoce/Trad. THIO
# 16          ASD  N09    Négoce PMMA&FPO
# 17          ASD  N13        Négoce CECA
# 18          ASD  N27    Négoce Oxygénés
# 19          ASD  N61       Négoce Kynar
# 20          ASD  N62    Négoce Coatings
# 21          ASD  N70         Négoce IPN
# 22          ASD  P01          Packaging
# 23          ASD  P08     Packaging THIO
# 24          ASD  R01       Raw material
# 25          ASD  R08  Raw material THIO
# 26          ASD  T01            Tolling
# 27          ASD  T08       Tolling THIO
# 28          ASD  S01             Sample
# 29          ASD  M01        Spare parts
# 30          ASD  M02      Miscellaneous
# 31          ATC  N14    Négoce Acrylics
# 32          ATC  P01          Packaging
# 33          ATC  R01       Raw material
# 34          ATC  T01            Tolling
# 35          ATC  S01             Sample
# 36          ATC  M01        Spare parts
# 37          ATC  M02      Miscellaneous

# %%
#one to many merge plant list with MRP controller list
#plantmrp_dfm = pd.merge(plant_dfm,mrp_dfm,on= 'dummy' )
plantmrp_dfm = pd.merge(plant_dfm,mrp_dfm,on= 'company desc' )
plantmrp_dfm
# Out:
#     plant                      plant desc       type country company  \
# 0    9DGQ          WAIGAOQIAO BONDED ZONE  WAREHOUSE      CN      9D
# 1    9DGQ          WAIGAOQIAO BONDED ZONE  WAREHOUSE      CN      9D
# 2    9DGQ          WAIGAOQIAO BONDED ZONE  WAREHOUSE      CN      9D
# 3    9DGQ          WAIGAOQIAO BONDED ZONE  WAREHOUSE      CN      9D
# 4    9DGQ          WAIGAOQIAO BONDED ZONE  WAREHOUSE      CN      9D
# 5    9DGQ          WAIGAOQIAO BONDED ZONE  WAREHOUSE      CN      9D
# 6    9DGQ          WAIGAOQIAO BONDED ZONE  WAREHOUSE      CN      9D
# 7    9DGQ          WAIGAOQIAO BONDED ZONE  WAREHOUSE      CN      9D
# 8    9DGQ          WAIGAOQIAO BONDED ZONE  WAREHOUSE      CN      9D
# 9    9DGQ          WAIGAOQIAO BONDED ZONE  WAREHOUSE      CN      9D
# 10   9DGQ          WAIGAOQIAO BONDED ZONE  WAREHOUSE      CN      9D
# 11   9DGQ          WAIGAOQIAO BONDED ZONE  WAREHOUSE      CN      9D
# 12   9DGQ          WAIGAOQIAO BONDED ZONE  WAREHOUSE      CN      9D
# 13   9DGQ          WAIGAOQIAO BONDED ZONE  WAREHOUSE      CN      9D
# 14   9DGQ          WAIGAOQIAO BONDED ZONE  WAREHOUSE      CN      9D
# 15   9DGQ          WAIGAOQIAO BONDED ZONE  WAREHOUSE      CN      9D
# 16   9DGQ          WAIGAOQIAO BONDED ZONE  WAREHOUSE      CN      9D
# 17   9DGQ          WAIGAOQIAO BONDED ZONE  WAREHOUSE      CN      9D
# 18   9DGU      WAIGAOQIAO NON BONDED ZONE  WAREHOUSE      CN      9D
# 19   9DGU      WAIGAOQIAO NON BONDED ZONE  WAREHOUSE      CN      9D
# 20   9DGU      WAIGAOQIAO NON BONDED ZONE  WAREHOUSE      CN      9D
# 21   9DGU      WAIGAOQIAO NON BONDED ZONE  WAREHOUSE      CN      9D
# 22   9DGU      WAIGAOQIAO NON BONDED ZONE  WAREHOUSE      CN      9D
# 23   9DGU      WAIGAOQIAO NON BONDED ZONE  WAREHOUSE      CN      9D
# 24   9DGU      WAIGAOQIAO NON BONDED ZONE  WAREHOUSE      CN      9D
# 25   9DGU      WAIGAOQIAO NON BONDED ZONE  WAREHOUSE      CN      9D
# 26   9DGU      WAIGAOQIAO NON BONDED ZONE  WAREHOUSE      CN      9D
# 27   9DGU      WAIGAOQIAO NON BONDED ZONE  WAREHOUSE      CN      9D
# 28   9DGU      WAIGAOQIAO NON BONDED ZONE  WAREHOUSE      CN      9D
# 29   9DGU      WAIGAOQIAO NON BONDED ZONE  WAREHOUSE      CN      9D
# ..    ...                             ...        ...     ...     ...
# 275  5KT1                KSK PLASTICS(SH)  WAREHOUSE      CN      5K
# 276  5KT1                KSK PLASTICS(SH)  WAREHOUSE      CN      5K
# 277  5KT1                KSK PLASTICS(SH)  WAREHOUSE      CN      5K
# 278  5KT1                KSK PLASTICS(SH)  WAREHOUSE      CN      5K
# 279  5K90  SARTOMER ASIA LIMITED(TRADING)    TRADING      CN      5K
# 280  5K90  SARTOMER ASIA LIMITED(TRADING)    TRADING      CN      5K
# 281  5K90  SARTOMER ASIA LIMITED(TRADING)    TRADING      CN      5K
# 282  5K90  SARTOMER ASIA LIMITED(TRADING)    TRADING      CN      5K
# 283  5K90  SARTOMER ASIA LIMITED(TRADING)    TRADING      CN      5K
# 284  5K90  SARTOMER ASIA LIMITED(TRADING)    TRADING      CN      5K
# 285  5K90  SARTOMER ASIA LIMITED(TRADING)    TRADING      CN      5K
# 286  5K90  SARTOMER ASIA LIMITED(TRADING)    TRADING      CN      5K
# 287  5K90  SARTOMER ASIA LIMITED(TRADING)    TRADING      CN      5K
# 288  5K90  SARTOMER ASIA LIMITED(TRADING)    TRADING      CN      5K
# 289  5K90  SARTOMER ASIA LIMITED(TRADING)    TRADING      CN      5K
# 290  5K90  SARTOMER ASIA LIMITED(TRADING)    TRADING      CN      5K
# 291  5K90  SARTOMER ASIA LIMITED(TRADING)    TRADING      CN      5K
# 292  5KFS                 FOREVERSUN TANK  WAREHOUSE      CN      5K
# 293  5KFS                 FOREVERSUN TANK  WAREHOUSE      CN      5K
# 294  5KFS                 FOREVERSUN TANK  WAREHOUSE      CN      5K
# 295  5KFS                 FOREVERSUN TANK  WAREHOUSE      CN      5K
# 296  5KFS                 FOREVERSUN TANK  WAREHOUSE      CN      5K
# 297  5KFS                 FOREVERSUN TANK  WAREHOUSE      CN      5K
# 298  5KFS                 FOREVERSUN TANK  WAREHOUSE      CN      5K
# 299  5KFS                 FOREVERSUN TANK  WAREHOUSE      CN      5K
# 300  5KFS                 FOREVERSUN TANK  WAREHOUSE      CN      5K
# 301  5KFS                 FOREVERSUN TANK  WAREHOUSE      CN      5K
# 302  5KFS                 FOREVERSUN TANK  WAREHOUSE      CN      5K
# 303  5KFS                 FOREVERSUN TANK  WAREHOUSE      CN      5K
# 304  5KFS                 FOREVERSUN TANK  WAREHOUSE      CN      5K
#
#     company desc MRPC               Name
# 0            ASD  N03   Négoce ADDITIVES
# 1            ASD  N06        Négoce PASP
# 2            ASD  N08  Négoce/Trad. THIO
# 3            ASD  N09    Négoce PMMA&FPO
# 4            ASD  N13        Négoce CECA
# 5            ASD  N27    Négoce Oxygénés
# 6            ASD  N61       Négoce Kynar
# 7            ASD  N62    Négoce Coatings
# 8            ASD  N70         Négoce IPN
# 9            ASD  P01          Packaging
# 10           ASD  P08     Packaging THIO
# 11           ASD  R01       Raw material
# 12           ASD  R08  Raw material THIO
# 13           ASD  T01            Tolling
# 14           ASD  T08       Tolling THIO
# 15           ASD  S01             Sample
# 16           ASD  M01        Spare parts
# 17           ASD  M02      Miscellaneous
# 18           ASD  N03   Négoce ADDITIVES
# 19           ASD  N06        Négoce PASP
# 20           ASD  N08  Négoce/Trad. THIO
# 21           ASD  N09    Négoce PMMA&FPO
# 22           ASD  N13        Négoce CECA
# 23           ASD  N27    Négoce Oxygénés
# 24           ASD  N61       Négoce Kynar
# 25           ASD  N62    Négoce Coatings
# 26           ASD  N70         Négoce IPN
# 27           ASD  P01          Packaging
# 28           ASD  P08     Packaging THIO
# 29           ASD  R01       Raw material
# ..           ...  ...                ...
# 275          ACL  T06       Tolling PASP
# 276          ACL  S01             Sample
# 277          ACL  M01        Spare parts
# 278          ACL  M02      Miscellaneous
# 279          ACL  N06        Négoce PASP
# 280          ACL  N14    Négoce Acrylics
# 281          ACL  N61       Négoce Kynar
# 282          ACL  N63    Négoce Sartomer
# 283          ACL  P01          Packaging
# 284          ACL  P06     Packaging PASP
# 285          ACL  R01       Raw material
# 286          ACL  R06  Raw material PASP
# 287          ACL  T01            Tolling
# 288          ACL  T06       Tolling PASP
# 289          ACL  S01             Sample
# 290          ACL  M01        Spare parts
# 291          ACL  M02      Miscellaneous
# 292          ACL  N06        Négoce PASP
# 293          ACL  N14    Négoce Acrylics
# 294          ACL  N61       Négoce Kynar
# 295          ACL  N63    Négoce Sartomer
# 296          ACL  P01          Packaging
# 297          ACL  P06     Packaging PASP
# 298          ACL  R01       Raw material
# 299          ACL  R06  Raw material PASP
# 300          ACL  T01            Tolling
# 301          ACL  T06       Tolling PASP
# 302          ACL  S01             Sample
# 303          ACL  M01        Spare parts
# 304          ACL  M02      Miscellaneous
#
# [305 rows x 8 columns]

# %%
plantmrp_dfm.to_excel('plantmrpcontroller.xlsx',sheet_name='sheet2')

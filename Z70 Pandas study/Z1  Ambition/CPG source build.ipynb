# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame

# ★★★★★★★★★★★★★★★★★★★★★★★★
# TODO: site path
ASHP_saleshist_path = r'Z:\32.W3 Shanghai ASHP\Forcasting and Planning\Picaso-Sales History\10.DR1\DPR\Picaso_Sales_history_(ASHP).xlsx'
ASHP_material_path = r'Z:\32.W3 Shanghai ASHP\Material Mapping\10.DR1\DPR\DPT_TEN_Material_Mapping_V1.xlsx'

ACL_saleshist_path = r'Z:\40.W3 HK-ACL\Forcasting and Planning\Picaso-Sales History\10.DR1\DPR\DPT_Picaso_Sales_history_(ALC-THIO).xlsx'
ACL_material_path = r'Z:\40.W3 HK-ACL\Material Mapping\10.DR1\DPR\DPT_TEN_Material_Mapping_V1.xlsx'

ARPIL_saleshist_path = r'Z:\31.W3 Cuddalore Peroxydes\Forcasting and Planning\Picaso-Sales History\10.DR1\DPR\DPT_TEX_Picaso-Sales History_ARPil.xls'
ARPIL_material_path = r'Z:\31.W3 Cuddalore Peroxydes\Material Mapping\10.DR1\DPR\DPT_TEN_Material_Mapping_V1.xlsx'

PMMA_saleshist_path = r'Z:\34.W3 Korea Jinhae and trading\Forcasting and Planning\Picaso-Sales History\10.DR1\DPR\DPT_Picaso_Sales_history_(ArkemaKorea).xlsx'
PMMA_material_path = r'Z:\34.W3 Korea Jinhae and trading\Material Mapping\10.DR1\DPR\DPT_TEN_Material_Mapping_V1.xlsx'

SEKI_saleshist_path = r'Z:\33.W3 Korea SEKI Peroxydes\Forcasting and Planning\Picaso-Sales History\10.DR1\DPR\DPT_Picaso_Sales_history_Seki_v0_20160628.xlsx'
SEKI_material_path = r'Z:\33.W3 Korea SEKI Peroxydes\Material Mapping\10.DR1\DPR\DPT_TEN_Material_Mapping_V1.xlsx'

ACC_saleshist_path = r'Z:\30.W3 Changshu ACC\Forcasting and Planning\Picaso-Sales History\10.DR1\DPR\Picaso_Sales_history_(ACC)160728.xlsx'
#for ACC mapping file, need addition step to process, ACC在scala物料后面加了-1,-2之类的,要去掉才能够mapping到
ACC_material_path = r'Z:\30.W3 Changshu ACC\Material Mapping\10.DR1\DPR\Ref\DPT_TEN_Material_Mapping-ACC for sales history mapping.xlsx'

PTE_saleshist_path = r'Z:\47.W3 Singapore\Forcasting and Planning\Picaso-Sales History\10.DR1\DPR\DPT_TEX_Picaso Sales History.xlsx'
PTE_material_path = r'Z:\47.W3 Singapore\Material Mapping\10.DR1\DPR\DPT_TEN_Material_Mapping_SG_V1.2.xlsx'

AKK_saleshist_path = r'Z:\44.W3 JP-ArkemaKK\Forcasting and Planning\Picaso-Sales History\10.DR1\DPR\DPT_Picaso_Sales_history_(ArkemaKK).xlsx'
AKK_material_path = r'Z:\44.W3 JP-ArkemaKK\Material Mapping\10.DR1\DPR\DPT_TEN_Material_Mapping_V1.xlsx'

ASD_saleshist_path = r'Z:\41.W3 CN-ASD\Forcasting and Planning\Picaso-Sales History\10.DR1\DPR\DPT_Picaso_Sales_history_(ASD).xlsx'
ASD_material_path = r'Z:\41.W3 CN-ASD\Material Mapping\10.DR1\DPR\DPT_TEN_Material_Mapping_V1.xlsx'

# TODO: key for processing which sites' data
# ASHP ; ACC ; ASD ; ACL ; AKK ; PTE; PMMA; SEKI; ARPIL ; ATC ;

processing = 'ASD'

if processing == 'ASHP':
    saleshist_path = ASHP_saleshist_path
    material_path = ASHP_material_path
    output_excel_name = 'C:\\Users\\A6013836\\Desktop\\Arkema\\00 Wave3\\30 dryrun1\\PICASO\\39 Sales history _review\\ASHP销售历史转换完.xlsx'

if processing == 'ACL':
    saleshist_path = ACL_saleshist_path
    material_path = ACL_material_path
    output_excel_name = 'C:\\Users\\A6013836\\Desktop\\Arkema\\00 Wave3\\30 dryrun1\\PICASO\\39 Sales history _review\\ACL销售历史转换完.xlsx'

if processing == 'ARPIL':  
    saleshist_path = ARPIL_saleshist_path
    material_path = ARPIL_material_path
    output_excel_name = 'C:\\Users\\A6013836\\Desktop\\Arkema\\00 Wave3\\30 dryrun1\\PICASO\\39 Sales history _review\\ARPIL销售历史转换完.xlsx'

if processing == 'PMMA':  
    saleshist_path = PMMA_saleshist_path
    material_path = PMMA_material_path
    output_excel_name = 'C:\\Users\\A6013836\\Desktop\\Arkema\\00 Wave3\\30 dryrun1\\PICASO\\39 Sales history _review\\PMMA销售历史转换完.xlsx'

if processing == 'SEKI':  
    saleshist_path = SEKI_saleshist_path
    material_path = SEKI_material_path
    output_excel_name = 'C:\\Users\\A6013836\\Desktop\\Arkema\\00 Wave3\\30 dryrun1\\PICASO\\39 Sales history _review\\SEKI销售历史转换完.xlsx'

if processing == 'ACC':  
    saleshist_path = ACC_saleshist_path
    material_path = ACC_material_path
    output_excel_name = 'C:\\Users\\A6013836\\Desktop\\Arkema\\00 Wave3\\30 dryrun1\\PICASO\\39 Sales history _review\\ACC销售历史转换完.xlsx'

if processing == 'PTE':  
    saleshist_path = PTE_saleshist_path
    material_path = PTE_material_path
    output_excel_name = 'C:\\Users\\A6013836\\Desktop\\Arkema\\00 Wave3\\30 dryrun1\\PICASO\\39 Sales history _review\\PTE销售历史转换完.xlsx'

if processing == 'AKK':  
    saleshist_path = AKK_saleshist_path
    material_path = AKK_material_path
    output_excel_name = 'C:\\Users\\A6013836\\Desktop\\Arkema\\00 Wave3\\30 dryrun1\\PICASO\\39 Sales history _review\\AKK销售历史转换完.xlsx'

if processing == 'ASD':  
    saleshist_path = ASD_saleshist_path
    material_path = ASD_material_path
    output_excel_name = 'C:\\Users\\A6013836\\Desktop\\Arkema\\00 Wave3\\30 dryrun1\\PICASO\\39 Sales history _review\\ASD销售历史转换完.xlsx'
    
# TODO: add notes and wave
s_notes = Series({'C8':'ASHP','H1':'ACL','I1':'APRIL','K1':'PMMA','K2':'SEKI','CC':'ACC','S1':'PTE','J1':'AKK','C4':'ASD'})
#s_wave = Series({'C8':'AW3-ASHP','H1':'AW3-ACL',})
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
